# %%
from google.colab import files

# Words that can query and be answer
files.upload()
# Out:
#      <input type="file" id="files-5216300f-e696-4da8-bed9-b0132e66b5bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5216300f-e696-4da8-bed9-b0132e66b5bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Words that can query but not be answer

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-94229d85-46c4-4394-8ed1-6ee49f955916" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94229d85-46c4-4394-8ed1-6ee49f955916">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
words = set()
query_words = set()

with open('wordles.txt', 'r') as f:
    file = f.readlines()
    for word in file:
        if word[0] != '#':
            words.add(word.strip())

with open('query_word.txt', 'r') as f:
    file = f.readlines()
    cnt = 0
    for word in file:
        if word[0] != '#':
            query_words.add(word.strip())

print(len(words))
print(len(query_words))
# Out:
# 2315
# 14855

# %%
import math

# 0: None(Gray)
# 1: Character is in answer but wrong position(Yellow)
# 2: Character is in answer and right position(Green)

# matching: compute the 0, 1, 2
def matching(answer, word):
    result = 0
    for i in range(5):
        result *= 3

        if answer[i] == word[i]:
            result += 2

        elif word[i] in answer:
            result += 1

    return result

# Node: generate the tree
class Node():
    def __init__(self, word_set):
        self.word_set = word_set
        self.word_cnt = [0] * pow(3, 5)

    def partition(self):
        max_information_gain = -1
        max_information_word = ''
        S = len(self.word_set)
        for partition_candidate in query_words:
            cnt = [0] * pow(3, 5)
            for word in self.word_set:
                cnt[matching(partition_candidate, word)] += 1
            information_gain = 0
            for i in range(pow(3, 5)):
                p = cnt[i] / S
                if p != 0:
                    information_gain -= p * math.log2(p)

            if information_gain > max_information_gain:
                max_information_gain = information_gain
                max_information_word = partition_candidate

        self.partition_word = max_information_word


    def guess(self):
        return self.partition_word

    def rt(self, resp):
        self.rt = set()
        for word in self.word_set:
            if matching(word, self.partition_word) == resp:
                self.rt.add(word)
        return self.rt

def zot_to_three(num):
    rt = 0
    for i in range(5):
        rt *= 3
        rt += int(num[i])

st = Node(words)
while True:
    st.partition()
    print(st.guess())
    resp = matching('grave', st.guess())
    if resp == pow(3, 5) - 1:
        print('Find!')
        print('Answer:', st.guess())
        break
    ns = st.rt(resp)
    if len(ns) == 1:
        print('Find!')
        print('Answer:', ns)
        break
    st = Node(ns)
# Out:
# salet
# beard
# cezve
# Find!
# Answer: {'grave'}
